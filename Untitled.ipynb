# %%
import time
from datetime import datetime, timezone
from pathlib import Path

import numpy as np
import pandas as pd
import requests
import matplotlib.pyplot as plt

# %matplotlib inline
pd.set_option("display.max_columns", None)

# %%
SYMBOL = "BTCUSDT"
INTERVAL = "1m"          # 1m, 3m, 5m, 15m, 30m, 1h, 4h, 1d, ...
START_DATE = "2023-01-01"  # UTC, inclusive
END_DATE = "2023-02-01"    # UTC, inclusive

MAX_FFILL_CANDLES = 3    # max consecutive missing candles to forward-fill during cleaning

RAW_DATA_PATH = Path(f"data/raw/{SYMBOL}_{INTERVAL}_raw.csv")
CLEAN_DATA_PATH = Path(f"data/processed/{SYMBOL}_{INTERVAL}_clean.parquet")
EDA_OUTPUT_DIR = Path("eda_output")

RAW_DATA_PATH.parent.mkdir(parents=True, exist_ok=True)
CLEAN_DATA_PATH.parent.mkdir(parents=True, exist_ok=True)
EDA_OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

# %%
BASE_URL = "https://api.binance.com"
KLINES_ENDPOINT = "/api/v3/klines"
MAX_CANDLES_PER_REQUEST = 1000
REQUEST_SLEEP_SECONDS = 0.3

KLINE_COLUMNS = [
    "open_time", "open", "high", "low", "close", "volume",
    "close_time", "quote_asset_volume", "num_trades",
    "taker_buy_base_volume", "taker_buy_quote_volume", "ignore",
]

INTERVAL_MS = {
    "1m": 60_000, "3m": 3 * 60_000, "5m": 5 * 60_000, "15m": 15 * 60_000,
    "30m": 30 * 60_000, "1h": 60 * 60_000, "4h": 4 * 60 * 60_000, "1d": 24 * 60 * 60_000,
}


def to_ms(date_str: str) -> int:
    dt = datetime.strptime(date_str, "%Y-%m-%d").replace(tzinfo=timezone.utc)
    return int(dt.timestamp() * 1000)


def fetch_klines(symbol, interval, start_ms, end_ms, session=None, max_retries=5):
    """Fetch all klines between start_ms and end_ms (inclusive), paginating as needed."""
    if interval not in INTERVAL_MS:
        raise ValueError(f"Unsupported interval '{interval}'. Known: {list(INTERVAL_MS)}")

    session = session or requests.Session()
    step_ms = INTERVAL_MS[interval]
    all_rows = []
    cursor = start_ms

    while cursor <= end_ms:
        params = {
            "symbol": symbol, "interval": interval,
            "startTime": cursor, "endTime": end_ms,
            "limit": MAX_CANDLES_PER_REQUEST,
        }

        rows = None
        for attempt in range(max_retries):
            try:
                resp = session.get(BASE_URL + KLINES_ENDPOINT, params=params, timeout=10)
                if resp.status_code == 429:
                    wait = 2 ** attempt
                    print(f"  Rate limited (429). Backing off {wait}s...")
                    time.sleep(wait)
                    continue
                resp.raise_for_status()
                rows = resp.json()
                break
            except requests.RequestException as exc:
                wait = 2 ** attempt
                print(f"  Request error ({exc}). Retrying in {wait}s...")
                time.sleep(wait)

        if rows is None:
            raise RuntimeError(f"Failed to fetch klines starting at {cursor} after {max_retries} retries")
        if not rows:
            break

        all_rows.extend(rows)
        last_open_time = rows[-1][0]
        next_cursor = last_open_time + step_ms
        if next_cursor <= cursor:
            break
        cursor = next_cursor

        print(f"  Fetched {len(rows):4d} candles up to "
              f"{datetime.fromtimestamp(last_open_time / 1000, tz=timezone.utc)} "
              f"(total so far: {len(all_rows)})")
        time.sleep(REQUEST_SLEEP_SECONDS)

    return all_rows


def klines_to_dataframe(rows):
    """Convert raw kline rows into a typed, tidy DataFrame."""
    df = pd.DataFrame(rows, columns=KLINE_COLUMNS)

    numeric_cols = ["open", "high", "low", "close", "volume",
                     "quote_asset_volume", "num_trades",
                     "taker_buy_base_volume", "taker_buy_quote_volume"]
    for col in numeric_cols:
        df[col] = pd.to_numeric(df[col], errors="coerce")

    df["open_time"] = pd.to_datetime(df["open_time"], unit="ms", utc=True)
    df["close_time"] = pd.to_datetime(df["close_time"], unit="ms", utc=True)

    df = df.drop(columns=["ignore"])
    df = df.sort_values("open_time").reset_index(drop=True)
    df = df.drop_duplicates(subset="open_time", keep="first").reset_index(drop=True)
    return df

# %%
start_ms = to_ms(START_DATE)
end_ms = to_ms(END_DATE)

print(f"Fetching {SYMBOL} {INTERVAL} candles from {START_DATE} to {END_DATE}...")
raw_rows = fetch_klines(SYMBOL, INTERVAL, start_ms, end_ms)
print(f"Fetched {len(raw_rows)} raw candles total.")

df_raw = klines_to_dataframe(raw_rows)
df_raw.to_csv(RAW_DATA_PATH, index=False)
print(f"Saved {len(df_raw)} candles to {RAW_DATA_PATH}")
df_raw.head()
# Out:
# Fetching BTCUSDT 1m candles from 2023-01-01 to 2023-02-01...
#   Fetched 1000 candles up to 2023-01-01 16:39:00+00:00 (total so far: 1000)
#   Fetched 1000 candles up to 2023-01-02 09:19:00+00:00 (total so far: 2000)
#   Fetched 1000 candles up to 2023-01-03 01:59:00+00:00 (total so far: 3000)
#   Fetched 1000 candles up to 2023-01-03 18:39:00+00:00 (total so far: 4000)
#   Fetched 1000 candles up to 2023-01-04 11:19:00+00:00 (total so far: 5000)
#   Fetched 1000 candles up to 2023-01-05 03:59:00+00:00 (total so far: 6000)
#   Fetched 1000 candles up to 2023-01-05 20:39:00+00:00 (total so far: 7000)
#   Fetched 1000 candles up to 2023-01-06 13:19:00+00:00 (total so far: 8000)
#   Fetched 1000 candles up to 2023-01-07 05:59:00+00:00 (total so far: 9000)
#   Fetched 1000 candles up to 2023-01-07 22:39:00+00:00 (total so far: 10000)
#   Fetched 1000 candles up to 2023-01-08 15:19:00+00:00 (total so far: 11000)
#   Fetched 1000 candles up to 2023-01-09 07:59:00+00:00 (total so far: 12000)
#   Fetched 1000 candles up to 2023-01-10 00:39:00+00:00 (total so far: 13000)
#   Fetched 1000 candles up to 2023-01-10 17:19:00+00:00 (total so far: 14000)
#   Fetched 1000 candles up to 2023-01-11 09:59:00+00:00 (total so far: 15000)
#   Fetched 1000 candles up to 2023-01-12 02:39:00+00:00 (total so far: 16000)
#   Fetched 1000 candles up to 2023-01-12 19:19:00+00:00 (total so far: 17000)
#   Fetched 1000 candles up to 2023-01-13 11:59:00+00:00 (total so far: 18000)
#   Fetched 1000 candles up to 2023-01-14 04:39:00+00:00 (total so far: 19000)
#   Fetched 1000 candles up to 2023-01-14 21:19:00+00:00 (total so far: 20000)
#   Fetched 1000 candles up to 2023-01-15 13:59:00+00:00 (total so far: 21000)
#   Fetched 1000 candles up to 2023-01-16 06:39:00+00:00 (total so far: 22000)
#   Fetched 1000 candles up to 2023-01-16 23:19:00+00:00 (total so far: 23000)
#   Fetched 1000 candles up to 2023-01-17 15:59:00+00:00 (total so far: 24000)
#   Fetched 1000 candles up to 2023-01-18 08:39:00+00:00 (total so far: 25000)
#   Fetched 1000 candles up to 2023-01-19 01:19:00+00:00 (total so far: 26000)
#   Fetched 1000 candles up to 2023-01-19 17:59:00+00:00 (total so far: 27000)
#   Fetched 1000 candles up to 2023-01-20 10:39:00+00:00 (total so far: 28000)
#   Fetched 1000 candles up to 2023-01-21 03:19:00+00:00 (total so far: 29000)
#   Fetched 1000 candles up to 2023-01-21 19:59:00+00:00 (total so far: 30000)
#   Fetched 1000 candles up to 2023-01-22 12:39:00+00:00 (total so far: 31000)
#   Fetched 1000 candles up to 2023-01-23 05:19:00+00:00 (total so far: 32000)
#   Fetched 1000 candles up to 2023-01-23 21:59:00+00:00 (total so far: 33000)
#   Fetched 1000 candles up to 2023-01-24 14:39:00+00:00 (total so far: 34000)
#   Fetched 1000 candles up to 2023-01-25 07:19:00+00:00 (total so far: 35000)
#   Fetched 1000 candles up to 2023-01-25 23:59:00+00:00 (total so far: 36000)
#   Fetched 1000 candles up to 2023-01-26 16:39:00+00:00 (total so far: 37000)
#   Fetched 1000 candles up to 2023-01-27 09:19:00+00:00 (total so far: 38000)
#   Fetched 1000 candles up to 2023-01-28 01:59:00+00:00 (total so far: 39000)
#   Fetched 1000 candles up to 2023-01-28 18:39:00+00:00 (total so far: 40000)
#   Fetched 1000 candles up to 2023-01-29 11:19:00+00:00 (total so far: 41000)
#   Fetched 1000 candles up to 2023-01-30 03:59:00+00:00 (total so far: 42000)
#   Fetched 1000 candles up to 2023-01-30 20:39:00+00:00 (total so far: 43000)
#   Fetched 1000 candles up to 2023-01-31 13:19:00+00:00 (total so far: 44000)
#   Fetched  641 candles up to 2023-02-01 00:00:00+00:00 (total so far: 44641)
# Fetched 44641 raw candles total.
# Saved 44641 candles to data\raw\BTCUSDT_1m_raw.csv
#                   open_time      open      high       low     close  \
# 0 2023-01-01 00:00:00+00:00  16541.77  16544.76  16538.45  16543.67
# 1 2023-01-01 00:01:00+00:00  16543.04  16544.41  16538.48  16539.31
# 2 2023-01-01 00:02:00+00:00  16539.31  16541.17  16534.52  16536.43
# 3 2023-01-01 00:03:00+00:00  16536.43  16537.28  16531.00  16533.65
# 4 2023-01-01 00:04:00+00:00  16534.12  16536.08  16527.51  16535.38
#
#       volume                       close_time  quote_asset_volume  num_trades  \
# 0   83.08143 2023-01-01 00:00:59.999000+00:00        1.374269e+06        2687
# 1   80.45300 2023-01-01 00:01:59.999000+00:00        1.330773e+06        2890
# 2   62.90197 2023-01-01 00:02:59.999000+00:00        1.040248e+06        1930
# 3  115.71894 2023-01-01 00:03:59.999000+00:00        1.913268e+06        2956
# 4  144.45369 2023-01-01 00:04:59.999000+00:00        2.388081e+06        3795
#
#    taker_buy_base_volume  taker_buy_quote_volume
# 0               40.18369            6.647060e+05
# 1               33.28428            5.505633e+05
# 2               20.73999            3.430094e+05
# 3               49.40758            8.169194e+05
# 4               76.52421            1.265080e+06
